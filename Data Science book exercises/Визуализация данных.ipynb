# %%
from matplotlib import pyplot as plt

years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]

# %%
#Создаем линейную диаграму, где x - годы, y - ВВП, цвет графика - зеленый, точки отмаркерованы
plt.plot(years, gdp, color = 'green', marker = 'o', linestyle = 'solid')

# Добавим имя графика
plt.title("Номинальный ВВП")

#Подпишем имя оси y
plt.ylabel("ВВП")

#Выведем график (на самомо деле юпитер и так его выведет)
plt.show()

# %%
#Создаем столбчатую диаграмму
movies = ["Энни Холл", "Бен-Гур", "Касабланка", "Ганди", "Вестсайдская история"]
num_oscars = [5, 11, 3, 8, 10]

#Ширина столбцов по умолчанию 0.8, поэтому добавим 0.1 к левым координам, чтобы каждый столбец был по центру интервала
xs = [i + 0.1 for i, _ in enumerate(movies)]

# %%
plt.bar(movies, num_oscars)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(xs, num_oscars)

plt.ylabel("Количество наград")
plt.title("Мои любимые фильмы")

#добавим метки на оси X с названиями фильмов в центре каждого интервала
plt.xticks([i + 0.1 for i, _ in enumerate(movies)], movies)

plt.show()

# %%
import collections

grades = [83, 95, 91, 87, 70, 0, 85, 82, 100, 67, 73, 77, 0]
decile = lambda grade: grade // 10 * 10 #Дециль - десятая часть числа
histogram = Counter(decile(grade) for grade in grades)

plt.bar([x - 4 for x in histogram.keys()],    #Сдвинуть столбец влево на 4
       histogram.values(),                    #Высота столбца
        8)                                    #Ширина каждого стобца

plt.axis([-5, 105, 0, 5]) #Ось X от -5 до 105
                          #Ось Y от 0 до 5
plt.xticks([10 * i for i in range(11)]) #Метки по оси X: 0, 10, ..., 100

plt.xlabel("Дециль")
plt.ylabel("Число студентов")
plt.title("Распределение оценок за экзамен")

plt.show()

# %%
variance = [1, 2, 4, 8, 16, 32, 64, 128, 256] #дисперсия
bias_squared = [256, 128, 64, 32, 16, 8, 4, 2, 1] #квадрат смещения

#Суммарая ошибка
total_error = [x + y for x, y in zip(variance, bias_squared)]
xs = [i for i, _ in enumerate(variance)]

plt.plot(xs, variance, 'g-', label = 'Дисперсия')
plt.plot(xs, bias_squared, 'r-.', label = 'Смещение^2')
plt.plot(xs, total_error, 'b:', label = 'Суммарная ошибка')

#loc = 9 означает "Наверху посередине"
plt.legend(loc = 9)
plt.xlabel("Сложность модели")
plt.title("Компромис между смещением и десперсией")

plt.show()

# %%
friends = [70, 65, 72, 63, 71, 64, 60, 64, 67]
minutes = [175, 170, 205, 120, 220, 130, 105, 145, 190]
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i']

plt.scatter(friends, minutes)

#Назначить метку для каждой точки
for label, friend_count, minute_count in zip(labels, friends, minutes):
    plt.annotate(label,
                 xy = (friend_count, minute_count),
                 xytext = (5, -5),
                 textcoords = 'offset points'
                 )

plt.title("Зависимость между количеством минут и числом друзей")
plt.xlabel("Число друзей")
plt.ylabel("Время проводимое на сайте ежедневно")

plt.show()

# %%
test_1_grades = [99, 90, 85, 97, 80] #Оценки за тест 1
test_2_grades = [100, 85, 60, 90, 70] #Оценки за тест 2

plt.scatter(test_1_grades, test_2_grades)
plt.title("Несопостовимые оси")
plt.xlabel("Оценки за первый тест")
plt.ylabel("Оценки за второй тест")
plt.axis("equal")
plt.show()

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

X=10
N=50
u=np.linspace(-X,X,N)
x,y=np.meshgrid(u,u)
r=np.sqrt(x**2+y**2)
z=np.sin(r)/r
fig=plt.figure()
ax=Axes3D(fig)
ax.plot_surface(x,y,z,rstride=1,cstride=1)

# %%
fig=plt.figure()
ax=Axes3D(fig)
ax.plot_surface(x,y,z,rstride=1,cstride=1,cmap='gnuplot')

# %%
n=256
u=np.linspace(0,1,n)
x,y=np.meshgrid(u,u)
z=np.zeros((n,n,3))
z[:,:,0]=x
z[:,:,2]=y
plt.imshow(z)
